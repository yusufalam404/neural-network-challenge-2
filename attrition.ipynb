# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras import layers

#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# 0               3  ...                  3                        1
# 1               2  ...                  4                        4
# 2               2  ...                  3                        2
# 3               3  ...                  3                        3
# 4               3  ...                  3                        4
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                 8                      0               1
# 1                 1                10                      3               3
# 2                 0                 7                      3               3
# 3                 0                 8                      3               3
# 4                 1                 6                      3               3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 27 columns]

# %%
# Determine the number of unique values in each column
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# Create y_df with the Attrition and Department columns
y_df = attrition_df[['Attrition', 'Department']]
y_df.head()
# Out:
#   Attrition              Department
# 0       Yes                   Sales
# 1        No  Research & Development
# 2       Yes  Research & Development
# 3        No  Research & Development
# 4        No  Research & Development

# %%
# Create a list of at least 10 column names to use as X data
selected_columns = ['Age',
           'BusinessTravel',
           'MaritalStatus',
           'DistanceFromHome',
           'Education',
           'EducationField',
           'EnvironmentSatisfaction',
           'JobInvolvement',
           'HourlyRate',
           'NumCompaniesWorked'
]

# Create X_df using your selected columns
X_df = attrition_df[selected_columns]
X_df.head()

# Show the data types for X_df
X_df.dtypes
# Out:
# Age                         int64
# BusinessTravel             object
# MaritalStatus              object
# DistanceFromHome            int64
# Education                   int64
# EducationField             object
# EnvironmentSatisfaction     int64
# JobInvolvement              int64
# HourlyRate                  int64
# NumCompaniesWorked          int64
# dtype: object

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_df, y_df,
    random_state=42
    )

# %%
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# Identify numeric and categorical columns *after* splitting the data
numeric_cols = X_train.select_dtypes(include=['int64','float64']).columns.tolist()
categorical_cols = X_train.select_dtypes(include=['object']).columns.tolist()


ohe_X = OneHotEncoder(handle_unknown='ignore')

# Fit and transform the categorical data using the identified columns
X_train_cat = ohe_X.fit_transform(X_train[categorical_cols]).toarray() 
X_test_cat  = ohe_X.transform(X_test[categorical_cols]).toarray()   

X_train_num = X_train[numeric_cols].values
X_test_num  = X_test[numeric_cols].values

X_train_enc = np.hstack([X_train_num, X_train_cat])
X_test_enc  = np.hstack([X_test_num,  X_test_cat])

# %%
from sklearn.preprocessing import OneHotEncoder

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_enc)
X_test_scaled  = scaler.transform(X_test_enc)

# %%
# Remove the 'sparse=False' argument
dept_ohe = OneHotEncoder(handle_unknown='ignore')
y_train_dept = dept_ohe.fit_transform(y_train[['Department']])
y_test_dept  = dept_ohe.transform(y_test[['Department']])

# Remove the 'sparse=False' argument
attr_ohe = OneHotEncoder(handle_unknown='ignore')
y_train_attr = attr_ohe.fit_transform(y_train[['Attrition']])
y_test_attr  = attr_ohe.transform(y_test[['Attrition']])

# Convert to dense arrays for use with the neural network
y_train_dept = y_train_dept.toarray()
y_test_dept = y_test_dept.toarray()
y_train_attr = y_train_attr.toarray()
y_test_attr = y_test_attr.toarray()

# %% [markdown]
# ## Part 2: Create, Compile, and Train the Model

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

input_dim = X_train_scaled.shape[1]
print("Input features:", input_dim)
# Out:
# Input features: 7

# %%
inputs = Input(shape=(input_dim,), name='input_layer')
shared = Dense(64, activation='relu')(inputs)
shared = Dense(32, activation='relu')(shared)

# %%
dept_branch = Dense(16, activation='relu')(shared)
dept_output = Dense(
    y_train_dept.shape[1],
    activation='softmax',
    name='department_output'
)(dept_branch)


attr_branch = Dense(16, activation='relu')(shared)
attr_output = Dense(
    y_train_attr.shape[1],
    activation='softmax',
    name='attrition_output'
)(attr_branch)

# %%
# Create the model
model = Model(inputs=inputs, outputs=[dept_output, attr_output])


# Compile the model
model.compile(
    optimizer='adam',
    loss={
        'department_output': 'categorical_crossentropy',
        'attrition_output':  'categorical_crossentropy'
    },
    metrics={
        'department_output': 'accuracy',
        'attrition_output':  'accuracy'
    }
)

# Summarize the model
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 7)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │
# Epoch 13/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8401 - attrition_output_loss: 0.3943 - department_output_accuracy: 0.6774 - department_output_loss: 0.6999 - loss: 1.0937 - val_attrition_output_accuracy: 0.7919 - val_attrition_output_loss: 0.4813 - val_department_output_accuracy: 0.6063 - val_department_output_loss: 0.8651 - val_loss: 1.3496
# Epoch 14/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8307 - attrition_output_loss: 0.4236 - department_output_accuracy: 0.6522 - department_output_loss: 0.7525 - loss: 1.1759 - val_attrition_output_accuracy: 0.7919 - val_attrition_output_loss: 0.4959 - val_department_output_accuracy: 0.6063 - val_department_output_loss: 0.8649 - val_loss: 1.3642
# Epoch 15/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8713 - attrition_output_loss: 0.3443 - department_output_accuracy: 0.6873 - department_output_loss: 0.6980 - loss: 1.0423 - val_attrition_output_accuracy: 0.7919 - val_attrition_output_loss: 0.4823 - val_department_output_accuracy: 0.6063 - val_department_output_loss: 0.8646 - val_loss: 1.3503
# Epoch 16/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_output_accuracy: 0.8436 - attrition_output_loss: 0.3997 - department_output_accuracy: 0.6668 - department_output_loss: 0.7339 - loss: 1.1337 - val_attrition_output_accuracy: 0.8009 - val_attrition_output_loss: 0.4856 - val_department_output_accuracy: 0.6063 - val_department_output_loss: 0.8681 - val_loss: 1.3572
# Epoch 17/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8368 - attrition_output_loss: 0.3985 - department_output_accuracy: 0.6780 - department_output_loss: 0.7070 - loss: 1.1055 - val_attrition_output_accuracy: 0.8009 - val_attrition_output_loss: 0.4998 - val_department_output_accuracy: 0.6063 - val_department_output_loss: 0.8673 - val_loss: 1.3705
# Epoch 18/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8476 - attrition_output_loss: 0.3754 - department_output_accuracy: 0.6653 - department_output_loss: 0.7138 - loss: 1.0893 - val_attrition_output_accuracy: 0.8009 - val_attrition_output_loss: 0.4841 - val_department_output_accuracy: 0.6063 - val_department_output_loss: 0.8726 - val_loss: 1.3603
# Epoch 19/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_output_accuracy: 0.8421 - attrition_output_loss: 0.3738 - department_output_accuracy: 0.6698 - department_output_loss: 0.7165 - loss: 1.0906 - val_attrition_output_accuracy: 0.8009 - val_attrition_output_loss: 0.4926 - val_department_output_accuracy: 0.6063 - val_department_output_loss: 0.8743 - val_loss: 1.3704
# Epoch 20/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_output_accuracy: 0.8609 - attrition_output_loss: 0.3452 - department_output_accuracy: 0.6422 - department_output_loss: 0.7467 - loss: 1.0916 - val_attrition_output_accuracy: 0.8009 - val_attrition_output_loss: 0.4919 - val_department_output_accuracy: 0.6063 - val_department_output_loss: 0.8786 - val_loss: 1.3740

# %%
# Evaluate the model with the testing data
eval_results = model.evaluate(
    X_test_scaled,
    [y_test_dept, y_test_attr]
)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8610 - attrition_output_loss: 0.4083 - department_output_accuracy: 0.6477 - department_output_loss: 0.8229 - loss: 1.2284

# %%
# Print the accuracy for both department and attrition
print(f"Department Test Accuracy: {eval_results[3]:.4f}")
print(f"Attrition Test Accuracy:  {eval_results[4]:.4f}")
# Out:
# Department Test Accuracy: 0.8696
# Attrition Test Accuracy:  0.6522

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# 2. What activation functions did you choose for your output layers, and why?
#
#
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1. Accuracy would not be the best metric due to the 0.6522 accuracy it has outputted.
# 2. I used sigmoid as my output layers.
# 3. Ways to improve the model:
#
#   1. experiment with adding/removing layers
#   2. collect more data
#   3. Look at recall, F1, ROC-AUC metrics
